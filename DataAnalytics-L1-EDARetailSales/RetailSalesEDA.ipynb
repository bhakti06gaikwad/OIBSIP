# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Loaded retail sales dataset
df = pd.read_csv("retail_sales.csv")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
# Performed initial dataset exploration
print("Shape:",df.shape)

df.info()

df.describe()

df.isnull().sum()
# Out:
# Shape: (1000, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# Removed duplicate records

print(df.duplicated().sum())

df=df.drop_duplicates()
# Out:
# 0

# %%
# Processed date column

df["Date"]=pd.to_datetime(df["Date"])

df["Year"]=df["Date"].dt.year

df["Month"]=df["Date"].dt.month_name()

df["Day"]=df["Date"].dt.day

# %%
#Added monthly sales analysis

monthly_sales=df.groupby("Month")["Total Amount"].sum()

plt.figure(figsize=(10,5))

monthly_sales.plot(kind="bar")

plt.title("Monthly Sales")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()

# %%
# Analyzed product category sales

category_sales=df.groupby("Product Category")["Total Amount"].sum()

plt.figure(figsize=(8,5))

category_sales.plot(kind="bar",color="green")

plt.title("Sales by Product Category")

plt.show()

# %%
# Added customer gender analysis

gender=df["Gender"].value_counts()

plt.figure(figsize=(5,5))

gender.plot(kind="pie",autopct="%1.1f%%")

plt.ylabel("")

plt.title("Customer Gender Distribution")

plt.show()

# %%
# Visualized customer age distribution

plt.figure(figsize=(8,5))

plt.hist(df["Age"],bins=10)

plt.title("Age Distribution")

plt.xlabel("Age")

plt.ylabel("Count")

plt.show()

# %%
# Created correlation heatmap

plt.figure(figsize=(8,5))

sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# Business Recommendations
# 1) Increase stock for the best-selling product category.
# 2) Launch marketing campaigns during low-sales months.
# 3) Offer discounts to improve sales in weaker categories.
# 4) Target promotions based on customer age groups.
# 5) Improve customer engagement through loyalty programs.
